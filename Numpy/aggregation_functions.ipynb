# %%
import numpy as np

# %%
data = np.arange(1,6)
data
# Out:
# array([1, 2, 3, 4, 5])

# %%
# sum
np.sum(data)
# Out:
# 15

# %%
# max
data.max()
# Out:
# 5

# %%
# min
data.min()
# Out:
# 1

# %%
# mean (avg)
data.mean()
# Out:
# 3.0

# %%
# variation 
data.var()
# Out:
# 2.0

# %%
# standard Daviation
data.std()
# Out:
# 1.4142135623730951

# %%
# Exponential
np.exp(data)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])
