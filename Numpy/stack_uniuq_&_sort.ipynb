# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([5,6,7])

# stack
st = np.stack((a,b))
print(st)
# Out:
# [[1 2 3]
#  [5 6 7]]

# %%
# hsatck
st = np.hstack((a,b))
st
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
# vstack
st = np.vstack((a,b))
st
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
arr = np.array([1,2,5,3,1,56,8,6,1,5,4,6,1])
result = np.unique(arr)
result
# Out:
# array([ 1,  2,  3,  4,  5,  6,  8, 56])

# %%
np.sort(arr)
# Out:
# array([ 1,  1,  1,  1,  2,  3,  4,  5,  5,  6,  6,  8, 56])
