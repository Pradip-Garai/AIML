# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4])
arr2 = np.array([5,6,7,8])
print(arr1," ",arr2)
# Out:
# [1 2 3 4]   [5 6 7 8]

# %%
# Addition
arr1 + arr2
# Out:
# array([ 6,  8, 10, 12])

# %%
# Subtraction
arr1 - arr2
# Out:
# array([-4, -4, -4, -4])

# %%
# Multiply
arr1 * arr2
# Out:
# array([ 5, 12, 21, 32])

# %%
# division
arr1 / arr2
# Out:
# array([0.2       , 0.33333333, 0.42857143, 0.5       ])

# %%
# remender
arr1 % arr2
# Out:
# array([1, 2, 3, 4])
